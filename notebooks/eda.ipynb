# %% [markdown]
# Employee Salary Data - EDA 📊

# %%
## 1. Import Libraries

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
## 2. Load Dataset

ata = pd.read_csv('../data/employee_data.csv')

# ✅ Debugging Columns
print("Columns in Data:", data.columns.tolist())
print(data.head())

# ✅ Clean column names (remove any leading/trailing spaces)
data.columns = data.columns.str.strip()

data.head()
# Out:
# Columns in Data: ['Experience', ' Education_Level', ' Job_Title', ' Location', ' Salary']
#    Experience  Education_Level                  Job_Title    Location   Salary
# 0           4           Master                  Tech Lead   Hyderabad   760466
# 1           7         Bachelor   Senior Software Engineer   Hyderabad   629404
# 2          12              PhD                    Manager        Pune  1219541
# 3           3         Bachelor                  Tech Lead   Hyderabad   668631
# 4           1         Bachelor                  Tech Lead        Pune   649766
#    Experience Education_Level                  Job_Title    Location   Salary
# 0           4          Master                  Tech Lead   Hyderabad   760466
# 1           7        Bachelor   Senior Software Engineer   Hyderabad   629404
# 2          12             PhD                    Manager        Pune  1219541
# 3           3        Bachelor                  Tech Lead   Hyderabad   668631
# ...

# %%
## 3. Data Summary

data.info()
data.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Experience       30 non-null     int64
#  1   Education_Level  30 non-null     object
#  2   Job_Title        30 non-null     object
#  3   Location         30 non-null     object
#  4   Salary           30 non-null     int64
# dtypes: int64(2), object(3)
# memory usage: 1.3+ KB
#        Experience        Salary
# count   30.000000  3.000000e+01
# mean     6.400000  8.114921e+05
# std      4.090359  2.330883e+05
# min      0.000000  4.463330e+05
# 25%      3.000000  6.344945e+05
# 50%      7.000000  7.446390e+05
# 75%     10.000000  1.029254e+06
# max     13.000000  1.219541e+06

# %%
## 4. Missing Values Check

data.isnull().sum()
# Out:
# Experience         0
# Education_Level    0
# Job_Title          0
# Location           0
# Salary             0
# dtype: int64

# %%
## 5. Salary Distribution

plt.figure(figsize=(8,5))
sns.histplot(data['Salary'], kde=True, color='skyblue')
plt.title('Salary Distribution')
plt.show()

# %%
## 6. Experience vs Salary

plt.figure(figsize=(8,5))
sns.scatterplot(x='Experience', y='Salary', data=data, hue='Education_Level')
plt.title('Experience vs Salary')
plt.show()

# %%
## 7. Salary by Job Title

plt.figure(figsize=(8,5))
sns.barplot(x='Job_Title', y='Salary', data=data)
plt.title('Average Salary by Job Title')
plt.xticks(rotation=45)
plt.show()

# %%
## 8. Salary by Location

plt.figure(figsize=(8,5))
sns.boxplot(x='Location', y='Salary', data=data)
plt.title('Salary by Location')
plt.show()

# %% [markdown]
# ✅ Conclusion: We visualized salary trends by various features to understand key salary influencers.
